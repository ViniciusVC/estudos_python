# %%
#Aula de Python 01
#Instale jupyter notbook na sua máquina local.

nome = "Gabriel" # Declarar variavel e atribuir uma string.
print(nome) # Mostre o conteudo da variavel nome.
# Out:
# Michel

# %%
nome = "Filipe" # Atribuir outra string a variavel nome.
nome # Mostre o conteudo da variavel nome.
# Out:
# 'Guilherme'

# %%
idade = 37 # 
idade # Mostre o conteudo da variavel idade.
# Out:
# 37

# %%
idade+3 # mostrara o calculo
# Out:
# 40

# %%
#Vamos criar uma função em Python
def mais_um_ano(idade):
  print("Rodou a funcao")
  return idade +1

# %%
#Chamar a função que foi criada
mais_um_ano(40)
# Out:
# Rodou a funcao
# 41

# %%
filme1 = "Toy Story 17"
filme2 = "A Xuxa xontra o Baixo Astral"
filme3 = "Matrix 1"
# Instanciar uma lista
filmes = ["Toy Story", filme2, filme3]
print(filmes)
# Out:
# ['Toy Story', 'A Xuxa xontra o Baixo Astral', 'Matrix 1']

# %%
def imprime_filmes(filmes_que_quero_imprimir):
  print("A lista de filmes que quero imprimir:")
  print(filmes_que_quero_imprimir[-1]) # Ultimo idem da lista.
  print(filmes_que_quero_imprimir[0]) # Primeiro item da lista

# %%
imprime_filmes(filmes)
# Out:
# A lista de filmes que quero imprimir:
# Matrix 1
# Toy Story

# %%
for filme in filmes:
  print(filme)
  print("...")
print("saiu do for")
# Out:
# Toy Story
# ...
# A Xuxa xontra o Baixo Astral
# ...
# Matrix 1
# ...
# saiu do for

# %%
def imprime_filmes_vertical(filmes_que_quero_imprimir):
  for filme in filmes_que_quero_imprimir:
    print(filme)

# %%
imprime_filmes_vertical(filmes)
# Out:
# Toy Story
# A Xuxa xontra o Baixo Astral
# Matrix 1

# %%
# criar um dicionario (JSON/Objeto)
dados = {"nome":"Vinicius",
         "idade":40,
         "empresa":"Oi"}
print(dados)
print(dados["nome"])
# Out:
# {'nome': 'Vinicius', 'idade': 40, 'empresa': 'Oi'}
# Vinicius
