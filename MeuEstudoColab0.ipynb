# %%
# Machine Learning: Tutorial prático usando apenas o navegador (é sensacional!!!)
# Problema de animais

# pelo longo?
# perna curta?
# faz auau?

porco1 = [0,1,0]
porco2 = [0,1,1]
porco3 = [1,1,0]

cachorro1 = [0,1,1]
cachorro2 = [1,0,1]
cachorro3 = [1,1,1]

#nada a ver com os de cima

treino_x = [porco1,porco2,porco3,cachorro1,cachorro2,cachorro3]
treino_y = [1,1,1,0,0,0] # 1==portco 0==cachorro

# %%
# Na sua maquina local é preciso instalar a biblioteca.
# Executando treino do modelo
from sklearn.svm import LinearSVC #importar biblioteca sklearn.svm (MODELO PRONTO)
modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
animal_misterioso = [1,1,1]
modelo. predict([animal_misterioso])
# Out:
# array([0])

# %%
misterio1=[1,1,1]
misterio2=[1,1,0]
misterio3=[0,1,1]
teste_x = [misterio1,misterio2,misterio3]
teste_y = [0,1,1]
previsoes = modelo.predict(teste_x)
previsoes
# Out:
# array([0, 1, 0])

# %%
from sklearn.metrics import accuracy_score #importar biblioteca sklearn.metrics (TAXA DE ACERTO).
accuracy_score(teste_y, previsoes)
# Out:
# 0.6666666666666666

# %%
# 
# existe bibliotecas para chute.
#
